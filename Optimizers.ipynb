# %% [markdown]
# <a href="https://colab.research.google.com/github/ParamAhuja/DL_Notebooks/blob/main/Optimizers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=250, noise=0.25, random_state=1)

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from keras import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping

# %%
from keras.optimizers import Adam, RMSprop, RMSprop, SGD, Adagrad
adam = Adam(learning_rate=0.01)
rms = RMSprop(learning_rate=0.01)
adagrad = Adagrad(learning_rate=0.01)
momentum = SGD(learning_rate=0.01, momentum=0.9)
nag = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
sgd = SGD(learning_rate=0.01)

# %%
callback = EarlyStopping(monitor="val_loss", patience=3)

# %%
model0 = Sequential()

model0.add(
    Dense(
        128, activation = "relu", input_dim = 2
    )
)
model0.add(
    Dense(
        128, activation = "relu"
    )
)
model0.add(
    Dense(
        1, activation = "sigmoid"
    )
)

model0.compile( loss = "binary_crossentropy", optimizer = adam, metrics = ["accuracy"])
model0.summary()
history = model0.fit(X, y, epochs = 100, batch_size = 10, callbacks = callback, validation_split=0.2, verbose = 1)

val_acc = history.history["val_accuracy"][-1]
val_loss = history.history["val_loss"][-1]
acc = history.history["accuracy"][-1]
loss = history.history["loss"][-1]
print(f" accuracy: {acc}\n val_accuracy: {val_acc}\n loss: {loss}\n val_loss: {val_loss}")
print("epochs: ", len(history.history["accuracy"]))
# Out:
# Model: "sequential_23"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_63 (Dense)                │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_64 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_65 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,025 (66.50 KB)
#  Trainable params: 17,025 (66.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7849 - loss: 0.4528 - val_accuracy: 0.6400 - val_loss: 0.7977
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8705 - loss: 0.3227 - val_accuracy: 0.7000 - val_loss: 0.5775
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8869 - loss: 0.2770 - val_accuracy: 0.6200 - val_loss: 0.7610
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9011 - loss: 0.2692 - val_accuracy: 0.7400 - val_loss: 0.5622
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9240 - loss: 0.2442 - val_accuracy: 0.7800 - val_loss: 0.5069
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9101 - loss: 0.2537 - val_accuracy: 0.7800 - val_loss: 0.4708
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9475 - loss: 0.2035 - val_accuracy: 0.7400 - val_loss: 0.6371
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9313 - loss: 0.1961 - val_accuracy: 0.8000 - val_loss: 0.5244
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9371 - loss: 0.2033 - val_accuracy: 0.8000 - val_loss: 0.6214
#  accuracy: 0.9350000023841858
#  val_accuracy: 0.800000011920929
#  loss: 0.19074051082134247
#  val_loss: 0.6213822364807129
# epochs:  9

# %%
model0 = Sequential()

model0.add(
    Dense(
        128, activation = "relu", input_dim = 2
    )
)
model0.add(
    Dense(
        128, activation = "relu"
    )
)
model0.add(
    Dense(
        1, activation = "sigmoid"
    )
)

model0.compile( loss = "binary_crossentropy", optimizer = rms, metrics = ["accuracy"])
model0.summary()
history = model0.fit(X, y, epochs = 100, batch_size = 10, callbacks = callback, validation_split=0.2, verbose = 1)


val_acc = history.history["val_accuracy"][-1]
val_loss = history.history["val_loss"][-1]
acc = history.history["accuracy"][-1]
loss = history.history["loss"][-1]
print(f" accuracy: {acc}\n val_accuracy: {val_acc}\n loss: {loss}\n val_loss: {val_loss}")
print("epochs: ", len(history.history["accuracy"]))
# Out:
# Model: "sequential_24"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_66 (Dense)                │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_67 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_68 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,025 (66.50 KB)
#  Trainable params: 17,025 (66.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8480 - loss: 0.4597 - val_accuracy: 0.6600 - val_loss: 0.5707
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8868 - loss: 0.2978 - val_accuracy: 0.6600 - val_loss: 0.7251
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9037 - loss: 0.2484 - val_accuracy: 0.8000 - val_loss: 0.4871
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9191 - loss: 0.2883 - val_accuracy: 0.7000 - val_loss: 0.6117
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9347 - loss: 0.2330 - val_accuracy: 0.7800 - val_loss: 0.4899
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9223 - loss: 0.2462 - val_accuracy: 0.7600 - val_loss: 0.6089
#  accuracy: 0.9300000071525574
#  val_accuracy: 0.7599999904632568
#  loss: 0.24111060798168182
#  val_loss: 0.6088621616363525
# epochs:  6

# %%
model0 = Sequential()

model0.add(
    Dense(
        128, activation = "relu", input_dim = 2
    )
)
model0.add(
    Dense(
        128, activation = "relu"
    )
)
model0.add(
    Dense(
        1, activation = "sigmoid"
    )
)

model0.compile( loss = "binary_crossentropy", optimizer = adagrad, metrics = ["accuracy"])
model0.summary()
history = model0.fit(X, y, epochs = 100, batch_size = 10, callbacks = callback, validation_split=0.2, verbose = 1)


val_acc = history.history["val_accuracy"][-1]
val_loss = history.history["val_loss"][-1]
acc = history.history["accuracy"][-1]
loss = history.history["loss"][-1]
print(f" accuracy: {acc}\n val_accuracy: {val_acc}\n loss: {loss}\n val_loss: {val_loss}")
print("epochs: ", len(history.history["accuracy"]))
# Out:
# Model: "sequential_25"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_69 (Dense)                │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_70 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_71 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,025 (66.50 KB)
#  Trainable params: 17,025 (66.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4858 - loss: 0.6866 - val_accuracy: 0.6200 - val_loss: 0.6598
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7717 - loss: 0.6264 - val_accuracy: 0.6200 - val_loss: 0.6304
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8136 - loss: 0.5823 - val_accuracy: 0.6200 - val_loss: 0.6078
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8357 - loss: 0.5260 - val_accuracy: 0.6200 - val_loss: 0.5913
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8077 - loss: 0.5096 - val_accuracy: 0.6800 - val_loss: 0.5797
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8728 - loss: 0.4546 - val_accuracy: 0.6600 - val_loss: 0.5738
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8245 - loss: 0.4420 - val_accuracy: 0.6600 - val_loss: 0.5729
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8707 - loss: 0.3902 - val_accuracy: 0.6400 - val_loss: 0.5767
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8718 - loss: 0.3778 - val_accuracy: 0.6400 - val_loss: 0.5825
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8655 - loss: 0.3648 - val_accuracy: 0.6400 - val_loss: 0.5915
#  accuracy: 0.8700000047683716
#  val_accuracy: 0.6399999856948853
#  loss: 0.35243746638298035
#  val_loss: 0.5915396809577942
# epochs:  10

# %%
model0 = Sequential()

model0.add(
    Dense(
        128, activation = "relu", input_dim = 2
    )
)
model0.add(
    Dense(
        128, activation = "relu"
    )
)
model0.add(
    Dense(
        1, activation = "sigmoid"
    )
)

model0.compile( loss = "binary_crossentropy", optimizer = nag, metrics = ["accuracy"])
model0.summary()
history = model0.fit(X, y, epochs = 100, batch_size = 10, callbacks = callback, validation_split=0.2, verbose = 1)


val_acc = history.history["val_accuracy"][-1]
val_loss = history.history["val_loss"][-1]
acc = history.history["accuracy"][-1]
loss = history.history["loss"][-1]
print(f" accuracy: {acc}\n val_accuracy: {val_acc}\n loss: {loss}\n val_loss: {val_loss}")
print("epochs: ", len(history.history["accuracy"]))
# Out:
# Model: "sequential_26"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_72 (Dense)                │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_73 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_74 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,025 (66.50 KB)
#  Trainable params: 17,025 (66.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7437 - loss: 0.6591 - val_accuracy: 0.6600 - val_loss: 0.6202
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8688 - loss: 0.5168 - val_accuracy: 0.6400 - val_loss: 0.5848
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8537 - loss: 0.4100 - val_accuracy: 0.6400 - val_loss: 0.6057
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8881 - loss: 0.3360 - val_accuracy: 0.6600 - val_loss: 0.6685
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8961 - loss: 0.2910 - val_accuracy: 0.6600 - val_loss: 0.6837
#  accuracy: 0.8799999952316284
#  val_accuracy: 0.6600000262260437
#  loss: 0.30955490469932556
#  val_loss: 0.6837228536605835
# epochs:  5

# %%
model0 = Sequential()

model0.add(
    Dense(
        128, activation = "relu", input_dim = 2
    )
)
model0.add(
    Dense(
        128, activation = "relu"
    )
)
model0.add(
    Dense(
        1, activation = "sigmoid"
    )
)

model0.compile( loss = "binary_crossentropy", optimizer = momentum, metrics = ["accuracy"])
model0.summary()
history = model0.fit(X, y, epochs = 100, batch_size = 10, callbacks = callback, validation_split=0.2, verbose = 1)


val_acc = history.history["val_accuracy"][-1]
val_loss = history.history["val_loss"][-1]
acc = history.history["accuracy"][-1]
loss = history.history["loss"][-1]
print(f" accuracy: {acc}\n val_accuracy: {val_acc}\n loss: {loss}\n val_loss: {val_loss}")
print("epochs: ", len(history.history["accuracy"]))
# Out:
# Model: "sequential_27"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_75 (Dense)                │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_76 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_77 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,025 (66.50 KB)
#  Trainable params: 17,025 (66.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5645 - loss: 0.6805 - val_accuracy: 0.6600 - val_loss: 0.6358
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8367 - loss: 0.5538 - val_accuracy: 0.6400 - val_loss: 0.5767
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8337 - loss: 0.4404 - val_accuracy: 0.6400 - val_loss: 0.5847
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8637 - loss: 0.3660 - val_accuracy: 0.6600 - val_loss: 0.6340
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9034 - loss: 0.2825 - val_accuracy: 0.6600 - val_loss: 0.6844
#  accuracy: 0.8849999904632568
#  val_accuracy: 0.6600000262260437
#  loss: 0.31405141949653625
#  val_loss: 0.6843764781951904
# epochs:  5

# %%
model0 = Sequential()

model0.add(
    Dense(
        128, activation = "relu", input_dim = 2
    )
)
model0.add(
    Dense(
        128, activation = "relu"
    )
)
model0.add(
    Dense(
        1, activation = "sigmoid"
    )
)

model0.compile( loss = "binary_crossentropy", optimizer = sgd, metrics = ["accuracy"])
model0.summary()
history = model0.fit(X, y, epochs = 100, batch_size = 10, callbacks = callback, validation_split=0.2, verbose = 1)


val_acc = history.history["val_accuracy"][-1]
val_loss = history.history["val_loss"][-1]
acc = history.history["accuracy"][-1]
loss = history.history["loss"][-1]
print(f" accuracy: {acc}\n val_accuracy: {val_acc}\n loss: {loss}\n val_loss: {val_loss}")
print("epochs: ", len(history.history["accuracy"]))
# Out:
# Model: "sequential_28"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_78 (Dense)                │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_79 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_80 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,025 (66.50 KB)
#  Trainable params: 17,025 (66.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7122 - loss: 0.6657 - val_accuracy: 0.6200 - val_loss: 0.6611
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8011 - loss: 0.6406 - val_accuracy: 0.6200 - val_loss: 0.6489
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8494 - loss: 0.6131 - val_accuracy: 0.6200 - val_loss: 0.6378
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7740 - loss: 0.6138 - val_accuracy: 0.6200 - val_loss: 0.6277
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8427 - loss: 0.5797 - val_accuracy: 0.6200 - val_loss: 0.6186
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8859 - loss: 0.5538 - val_accuracy: 0.6400 - val_loss: 0.6106
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8633 - loss: 0.5404 - val_accuracy: 0.6800 - val_loss: 0.6031
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8110 - loss: 0.5374 - val_accuracy: 0.6800 - val_loss: 0.5964
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8272 - loss: 0.5140 - val_accuracy: 0.6800 - val_loss: 0.5905
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8506 - loss: 0.5029 - val_accuracy: 0.6800 - val_loss: 0.5852
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8240 - loss: 0.5144 - val_accuracy: 0.6800 - val_loss: 0.5810
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8088 - loss: 0.4995 - val_accuracy: 0.6600 - val_loss: 0.5775
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8692 - loss: 0.4417 - val_accuracy: 0.6600 - val_loss: 0.5750
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8756 - loss: 0.4491 - val_accuracy: 0.6600 - val_loss: 0.5733
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8510 - loss: 0.4414 - val_accuracy: 0.6600 - val_loss: 0.5725
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8659 - loss: 0.4281 - val_accuracy: 0.6600 - val_loss: 0.5722
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8735 - loss: 0.4069 - val_accuracy: 0.6400 - val_loss: 0.5727
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8317 - loss: 0.4528 - val_accuracy: 0.6400 - val_loss: 0.5737
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8827 - loss: 0.3742 - val_accuracy: 0.6400 - val_loss: 0.5752
#  accuracy: 0.8849999904632568
#  val_accuracy: 0.6399999856948853
#  loss: 0.3856678903102875
#  val_loss: 0.5752114057540894
# epochs:  19
