# %% [markdown]
# <a href="https://colab.research.google.com/github/ParamAhuja/DL_Notebooks/blob/main/ImageClassifierCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from huggingface_hub import login
from datasets import load_dataset
from google.colab import userdata
HF_TOKEN = userdata.get('HF_TOKEN')
login(HF_TOKEN)
# Out:
# README.md:   0%|          | 0.00/608 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/459M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/113M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/20000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5000 [00:00<?, ? examples/s]

# %%
from datasets import load_dataset

# Load the dataset from the Hugging Face Hub
dataset_from_hub = load_dataset("ParamDev/DogsVsCats")

# You can now access the splits, for example:
train_data = dataset_from_hub["train"]
test_data = dataset_from_hub["test"]

# Display the dataset structure
print(dataset_from_hub)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 20000
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 5000
#     })
# })
